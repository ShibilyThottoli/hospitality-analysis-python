# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("datasets/fact_bookings.csv")
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_date = pd.read_csv('datasets/dim_date.csv')
df_hotels = pd.read_csv('datasets/dim_hotels.csv')
df_rooms = pd.read_csv('datasets/dim_rooms.csv')
df_agg_bookings = pd.read_csv('datasets/fact_aggregated_bookings.csv')

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.city.category().categorysort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings = df_bookings[df_bookings.no_guests>0]

# %%
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.revenue_generated.min() ,  df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
mean,std = df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
mean , std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
higher_limit = mean+3*std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
lower_limit = mean-3*std
lower_limit
# Out:
# np.float64(-263742.4278567056)

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<higher_limit]

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
mean,std = df_bookings.revenue_realized.mean(),df_bookings.revenue_realized.std()
higher_limit = mean+3*std
higher_limit
# Out:
# np.float64(33479.358661845814)

# %%
df_bookings[df_bookings.room_category=='RT4'].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings["occu_pct"] = df_agg_bookings["successful_bookings"]/df_agg_bookings["capacity"]
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#            occ_pct    oc_pct  occu_pct
# ...

# %%
df_agg_bookings["occu_pct"] = df_agg_bookings["occu_pct"].apply(
    lambda x: round(x*100, 2)
)

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#         occ_pct    oc_pct  occu_pct
# 0  8.333330e+17  0.833333     83.33
# 1  9.333330e+17  0.933333     93.33
# 2  7.666670e+17  0.766667     76.67
# 3  1.578947e+18  1.578947    157.89
# 4  9.473680e+17  0.947368     94.74

# %%
df_agg_bookings.drop(columns=['occ_pct', 'oc_pct'], inplace=True)

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occu_pct
# 0     83.33
# 1     93.33
# 2     76.67

# %% [markdown]
# **1.What is the average occupancy rate in each of the room categories?**

# %%
df_agg_bookings.groupby("room_category")["occu_pct"].mean().round()
# Out:
# room_category
# RT1    58.0
# RT2    58.0
# RT3    58.0
# RT4    59.0
# Name: occu_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_rooms,df_agg_bookings,left_on="room_id",right_on="room_category")

# %%
df.head()
# Out:
#   room_id room_class  property_id check_in_date room_category  \
# 0     RT1   Standard        16559      1-May-22           RT1
# 1     RT1   Standard        19562      1-May-22           RT1
# 2     RT1   Standard        19563      1-May-22           RT1
# 3     RT1   Standard        17558      1-May-22           RT1
# 4     RT1   Standard        16558      1-May-22           RT1
#
#    successful_bookings  capacity  occu_pct
# 0                   25      30.0     83.33
# 1                   28      30.0     93.33
# 2                   23      30.0     76.67
# 3                   30      19.0    157.89
# 4                   18      19.0     94.74

# %%
df.groupby("room_class")["occu_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occu_pct, dtype: float64

# %%
df.drop('room_category', axis=1, inplace=True)
df.head()
# Out:
#   room_id room_class  property_id check_in_date  successful_bookings  \
# 0     RT1   Standard        16559      1-May-22                   25
# 1     RT1   Standard        19562      1-May-22                   28
# 2     RT1   Standard        19563      1-May-22                   23
# 3     RT1   Standard        17558      1-May-22                   30
# 4     RT1   Standard        16558      1-May-22                   18
#
#    capacity  occu_pct
# 0      30.0     83.33
# 1      30.0     93.33
# 2      30.0     76.67
# 3      19.0    157.89
# 4      19.0     94.74

# %% [markdown]
# **2.Print average occupancy per city**

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df,df_hotels,on="property_id")

# %%
df.head()
# Out:
#   room_id room_class  property_id check_in_date  successful_bookings  \
# 0     RT1   Standard        16559      1-May-22                   25
# 1     RT1   Standard        19562      1-May-22                   28
# 2     RT1   Standard        19563      1-May-22                   23
# 3     RT1   Standard        17558      1-May-22                   30
# 4     RT1   Standard        16558      1-May-22                   18
#
#    capacity  occu_pct  property_name  category       city
# 0      30.0     83.33  Atliq Exotica    Luxury     Mumbai
# 1      30.0     93.33      Atliq Bay    Luxury  Bangalore
# 2      30.0     76.67   Atliq Palace  Business  Bangalore
# 3      19.0    157.89   Atliq Grands    Luxury     Mumbai
# 4      19.0     94.74   Atliq Grands    Luxury      Delhi

# %%
df.groupby("city")["occu_pct"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **3.When was the occupancy better? Weekend or Weekday?**

# %%
df.head()
# Out:
#   room_id room_class  property_id check_in_date  successful_bookings  \
# 0     RT1   Standard        16559      1-May-22                   25
# 1     RT1   Standard        19562      1-May-22                   28
# 2     RT1   Standard        19563      1-May-22                   23
# 3     RT1   Standard        17558      1-May-22                   30
# 4     RT1   Standard        16558      1-May-22                   18
#
#    capacity  occu_pct  property_name  category       city
# 0      30.0     83.33  Atliq Exotica    Luxury     Mumbai
# 1      30.0     93.33      Atliq Bay    Luxury  Bangalore
# 2      30.0     76.67   Atliq Palace  Business  Bangalore
# 3      19.0    157.89   Atliq Grands    Luxury     Mumbai
# 4      19.0     94.74   Atliq Grands    Luxury      Delhi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   room_id              9200 non-null   object
#  1   room_class           9200 non-null   object
#  2   property_id          9200 non-null   int64
#  3   check_in_date        9200 non-null   object
#  4   successful_bookings  9200 non-null   int64
#  5   capacity             9198 non-null   float64
#  6   occu_pct             9198 non-null   float64
#  7   property_name        9200 non-null   object
#  8   category             9200 non-null   object
#  9   city                 9200 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 718.9+ KB

# %%
df = pd.merge(df,df_date,left_on="check_in_date",right_on="date")
df
# Out:
#      room_id    room_class  property_id check_in_date  successful_bookings  \
# 0        RT1      Standard        18560     10-May-22                   19
# 1        RT1      Standard        19562     10-May-22                   18
# 2        RT1      Standard        19563     10-May-22                   16
# 3        RT1      Standard        17558     10-May-22                   11
# 4        RT1      Standard        16558     10-May-22                   10
# ...      ...           ...          ...           ...                  ...
# 6495     RT4  Presidential        16563     31-Jul-22                   13
# 6496     RT4  Presidential        16559     31-Jul-22                   13
# 6497     RT4  Presidential        17558     31-Jul-22                    3
# 6498     RT4  Presidential        19563     31-Jul-22                    3
# 6499     RT4  Presidential        17561     31-Jul-22                    3
#
# ...

# %%
df.groupby("day_type")["occu_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occu_pct, dtype: float64

# %% [markdown]
# **4.In the month of June,  what is the occupancy for differnt cities**

# %%
df_june_22 = df[df["mmm yy"]=="Jun 22"]
df_june_22.head()
# Out:
#     room_id room_class  property_id check_in_date  successful_bookings  \
# 550     RT1   Standard        16559     10-Jun-22                   20
# 551     RT1   Standard        19562     10-Jun-22                   19
# 552     RT1   Standard        19563     10-Jun-22                   17
# 553     RT1   Standard        17558     10-Jun-22                    9
# 554     RT1   Standard        16558     10-Jun-22                   11
#
#      capacity  occu_pct  property_name  category       city       date  \
# 550      30.0     66.67  Atliq Exotica    Luxury     Mumbai  10-Jun-22
# 551      30.0     63.33      Atliq Bay    Luxury  Bangalore  10-Jun-22
# 552      30.0     56.67   Atliq Palace  Business  Bangalore  10-Jun-22
# 553      19.0     47.37   Atliq Grands    Luxury     Mumbai  10-Jun-22
# 554      19.0     57.89   Atliq Grands    Luxury      Delhi  10-Jun-22
#
#      mmm yy week no  day_type
# 550  Jun 22    W 24  weekeday
# 551  Jun 22    W 24  weekeday
# ...

# %%
df_june_22.groupby("city")["occu_pct"].mean().round(2)
# Out:
# city
# Bangalore    56.58
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Name: occu_pct, dtype: float64

# %%
df_august = pd.read_csv("datasets/new_data_august.csv")
df_august.head()
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['room_id', 'room_class', 'property_id', 'check_in_date',
#        'successful_bookings', 'capacity', 'occu_pct', 'property_name',
#        'category', 'city', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
latest_df = pd.concat([df, df_august],ignore_index=True,axis=0)
latest_df.tail(10)
# Out:
#      room_id    room_class  property_id check_in_date  successful_bookings  \
# 6497     RT4  Presidential        17558     31-Jul-22                    3
# 6498     RT4  Presidential        19563     31-Jul-22                    3
# 6499     RT4  Presidential        17561     31-Jul-22                    3
# 6500     NaN      Standard        16559     01-Aug-22                   30
# 6501     NaN      Standard        19562     01-Aug-22                   21
# 6502     NaN      Standard        19563     01-Aug-22                   23
# 6503     NaN      Standard        19558     01-Aug-22                   30
# 6504     NaN      Standard        19560     01-Aug-22                   20
# 6505     NaN      Standard        17561     01-Aug-22                   18
# 6506     NaN      Standard        17564     01-Aug-22                   10
#
#       capacity  occu_pct  property_name  category       city       date  \
# ...

# %% [markdown]
# **6. Print revenue realized per city**

# %% [markdown]
# df_bookings_all = pd.merge(df_bookins,df_hotels,on="property_id")

# %%
df_bookings_all = pd.merge(df_bookings,df_hotels,on="property_id")
df_bookings_all
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22      1/5/2022
# 1        May012216558RT15        16558     27-04-22      1/5/2022
# 2        May012216558RT16        16558     1/5/2022      1/5/2022
# 3        May012216558RT17        16558     28-04-22      1/5/2022
# 4        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134568   Jul312217564RT45        17564     30-07-22      31-07-22
# 134569   Jul312217564RT46        17564     29-07-22      31-07-22
# 134570   Jul312217564RT48        17564     30-07-22      31-07-22
# 134571   Jul312217564RT49        17564     29-07-22      31-07-22
# 134572  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **7.Print month by month revenue**

# %%
df_date["date"] = pd.to_datetime(df_date["date"])
df_date.head(3)
# Out:
# C:\Users\shibi\AppData\Local\Temp\ipykernel_9632\173964601.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date["date"] = pd.to_datetime(df_date["date"])
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_bookings_all["check_in_date"].unique()
# Out:
# array(['1/5/2022', '2/5/2022', '3/5/2022', '4/5/2022', '5/5/2022',
#        '6/5/2022', '7/5/2022', '8/5/2022', '9/5/2022', '10/5/2022',
#        '11/5/2022', '12/5/2022', '13-05-22', '14-05-22', '15-05-22',
#        '16-05-22', '17-05-22', '18-05-22', '19-05-22', '20-05-22',
#        '21-05-22', '22-05-22', '23-05-22', '24-05-22', '25-05-22',
#        '26-05-22', '27-05-22', '28-05-22', '29-05-22', '30-05-22',
#        '31-05-22', '1/6/2022', '2/6/2022', '3/6/2022', '4/6/2022',
#        '5/6/2022', '6/6/2022', '7/6/2022', '8/6/2022', '9/6/2022',
#        '10/6/2022', '11/6/2022', '12/6/2022', '13-06-22', '14-06-22',
#        '15-06-22', '16-06-22', '17-06-22', '18-06-22', '19-06-22',
#        '20-06-22', '21-06-22', '22-06-22', '23-06-22', '24-06-22',
#        '25-06-22', '26-06-22', '27-06-22', '28-06-22', '29-06-22',
#        '30-06-22', '1/7/2022', '2/7/2022', '3/7/2022', '4/7/2022',
#        '5/7/2022', '6/7/2022', '7/7/2022', '8/7/2022', '9/7/2022',
# ...

# %%
df_bookings_all["check_in_date"] = pd.to_datetime(
    df_bookings_all["check_in_date"],
    errors="coerce"
)
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-01-05      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-01-05      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-01-05      3/5/2022
# 3  May012216558RT17        16558     28-04-22    2022-01-05      6/5/2022
# 4  May012216558RT18        16558     26-04-22    2022-01-05      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      55790 non-null   datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_bookings_all = pd.merge(df_bookings_all,df_date,left_on="check_in_date",right_on="date")

# %%
df_bookings_all.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1  May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2  May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
# 3  May052216558RT14        16558     3/5/2022    2022-05-05      6/5/2022
# 4  May052216558RT15        16558     30-04-22    2022-05-05     10/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        3.0           RT1         tripster            5.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        3.0           RT1   direct offline            5.0    Checked Out
# 3        2.0           RT1         tripster            3.0    Checked Out
# 4        4.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# ...

# %%
df_bookings_all.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    60278496
# Jun 22    52903014
# May 22    60961428
# Name: revenue_realized, dtype: int64

# %%
df_bookings_allgroupby()
